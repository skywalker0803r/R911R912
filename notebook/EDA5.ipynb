# %%
import requests
url = 'https://gist.githubusercontent.com/skywalker0803r/e0ef295d69aba240e6ff1537be354bc8/raw/eab83e022de41cfedf1644bd4e5752c97b2488f8/Modeling.py'
exec(requests.get(url).text)
url = 'https://gist.githubusercontent.com/skywalker0803r/c92f4651ccbd0640c2a8c97c017092d9/raw/adedbf1159e92402f32b8d961f6db70a1b0c95ad/DataPreprocessingArmory.py'
exec(requests.get(url).text)

# %%
xf = "ARO2-LIMS-S708@A9"
xe = "ARO2-LIMS-S907@PX"
xr = "ARO2-LIMS-S905@PX"
可控變數 = ["ARO2-DCS-R911_2_A_FA",
    "ARO2-DCS-R911_2_HF",
    "ARO2-DCS-R911_2_L2_A",
    "ARO2-DCS-R911_2_L3_A",
    "ARO2-DCS-R911_2_L4_A",
    "ARO2-DCS-R911_2_XF",
    ]
不可控變數 = [
    "ARO2-DCS-FI914A2",
    "ARO2-DCS-FI914A3",
    "ARO2-DCS-FI91601",
    "ARO2-DCS-FI91701",
    "ARO2-DCS-FI93201",
    "ARO2-DCS-FI94701",
    "ARO2-LIMS-S708@Br.Index",
    "ARO2-LIMS-S708@A9",
    "ARO2-LIMS-S708@A10+",
    "ARO2-LIMS-S708@Water",
    "ARO2-LIMS-S708@Sulfur",
    "ARO2-LIMS-S905@Water",
    "ARO2-LIMS-S907@Water",
]

# %% [markdown]
# # df_x

# %%
import pandas as pd
df_x = pd.read_excel('../data/FCFC_ARO_900/R911R912 _明志蔡教授_R2.xlsx',sheet_name='R911R912_TAG相關錶點資料(X)')
df_x
# Out:
#        Unnamed: 0  Unnamed: 1          Unnamed: 2 ARO2-DCS-FI91304  \
# 0             NaN         NaN 2017-01-01 00:00:00          3.47454
# 1             NaN         NaN 2017-01-01 01:00:00           3.5263
# 2             NaN         NaN 2017-01-01 02:00:00          3.50952
# 3             NaN         NaN 2017-01-01 03:00:00          3.41844
# 4             NaN         NaN 2017-01-01 04:00:00          3.49544
# ...           ...         ...                 ...              ...
# 38492         NaN         NaN 2021-05-23 20:00:00          3.46242
# 38493         NaN         NaN 2021-05-23 21:00:00          3.45939
# 38494         NaN         NaN 2021-05-23 22:00:00          3.44003
# 38495         NaN         NaN 2021-05-23 23:00:00          3.44483
# 38496         NaN         NaN 2021-05-24 00:00:00           3.5039
#
#       ARO2-DCS-FI91401 ARO2-DCS-FI914A2 ARO2-DCS-FI914A3 ARO2-DCS-FI914B2  \
# 0              1497.95           1494.6          1784.32          1487.99
# 1              1495.14          1562.32           1782.8          1483.48
# 2              2083.71          2066.14          1804.13          2071.64
# 3              2058.17          2054.37          1769.39          2058.04
# 4              2062.55          2064.68          1792.09          2066.45
# ...                ...              ...              ...              ...
# 38492          1199.82          1192.47          1503.36           1191.8
# 38493          1178.19          1192.97          1512.72          1196.05
# 38494          1204.05          1190.87           1518.1          1190.46
# 38495          1810.54           1847.3          1559.11          1851.47
# 38496          1833.58          1851.69          1558.41          1856.75
#
#       ARO2-DCS-FI914B3 ARO2-DCS-FI91501  ... ARO2-LIMS-S708@A10+ Unnamed: 76  \
# 0              1770.95          25.9889  ...                 NaN         NaN
# 1              1774.38           23.069  ...                 0.0         NaN
# 2              1793.95          22.9811  ...                 NaN         NaN
# 3              1770.95          23.0346  ...                 NaN         NaN
# 4              1770.95          22.9907  ...                 NaN         NaN
# ...                ...              ...  ...                 ...         ...
# 38492          1516.57          23.8182  ...                 NaN         NaN
# 38493          1494.92          21.9021  ...                 NaN         NaN
# 38494          1494.92            23.37  ...                 NaN         NaN
# 38495          1540.92          23.6394  ...                 NaN         NaN
# 38496          1563.93          23.3438  ...                 NaN         NaN
#
#       ARO2-LIMS-S708@Water Unnamed: 78 ARO2-LIMS-S708@Sulfur Unnamed: 80  \
# 0                      NaN         NaN                   NaN         NaN
# 1                78.699997         NaN                  0.04         NaN
# 2                      NaN         NaN                   NaN         NaN
# 3                      NaN         NaN                   NaN         NaN
# 4                      NaN         NaN                   NaN         NaN
# ...                    ...         ...                   ...         ...
# 38492                  NaN         NaN                   NaN         NaN
# 38493                  NaN         NaN                   NaN         NaN
# 38494                  NaN         NaN                   NaN         NaN
# 38495                  NaN         NaN                   NaN         NaN
# 38496                  NaN         NaN                   NaN         NaN
#
#       新增補充錶點 ARO2-LIMS-s919@A9 ARO2-LIMS-s919@A10+ ARO2-LIMS-s919@Br.Index
# 0        NaN               NaN                 NaN                     NaN
# 1        NaN             614.0              5298.0                     NaN
# 2        NaN               NaN                 NaN                     NaN
# 3        NaN               NaN                 NaN                     NaN
# 4        NaN               NaN                 NaN                     NaN
# ...      ...               ...                 ...                     ...
# 38492    NaN               NaN                 NaN                     NaN
# 38493    NaN               NaN                 NaN                     NaN
# 38494    NaN               NaN                 NaN                     NaN
# 38495    NaN               NaN                 NaN                     NaN
# 38496    NaN               NaN                 NaN                     NaN
#
# [38497 rows x 85 columns]

# %% [markdown]
# # df_y

# %%
df_y = pd.read_excel('../data/FCFC_ARO_900/R911R912 _明志蔡教授_R2.xlsx',sheet_name='目標值(Y)相關錶點資料')
df_y
# Out:
#        新增補充錶點          Unnamed: 1  ARO2-LIMS-S708@PX  ARO2-LIMS-S907@PX  \
# 0         NaN 2017-01-01 00:00:00                NaN                NaN
# 1         NaN 2017-01-01 01:00:00             23.077          34.433998
# 2         NaN 2017-01-01 02:00:00                NaN                NaN
# 3         NaN 2017-01-01 03:00:00                NaN                NaN
# 4         NaN 2017-01-01 04:00:00                NaN                NaN
# ...       ...                 ...                ...                ...
# 38493     NaN 2021-05-23 21:00:00                NaN                NaN
# 38494     NaN 2021-05-23 22:00:00                NaN                NaN
# 38495     NaN 2021-05-23 23:00:00                NaN                NaN
# 38496     NaN 2021-05-24 00:00:00                NaN                NaN
# 38497     NaN                 NaT                NaN                NaN
#
#        ARO2-LIMS-S905@PX  ARO2-LIMS-s922@EB  ARO2-LIMS-s922@PX  \
# 0                    NaN                NaN                NaN
# 1                  0.409              768.0          99.699997
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 38493                NaN                NaN                NaN
# 38494                NaN                NaN                NaN
# 38495                NaN                NaN                NaN
# 38496                NaN                NaN                NaN
# 38497                NaN                NaN                NaN
#
#        ARO2-LIMS-s922@MX  ARO2-LIMS-s922@OX  ARO2-DCS-PX@Recovery
# 0                    NaN                NaN                   NaN
# 1                 1330.0              521.0                 96.28
# 2                    NaN                NaN                   NaN
# 3                    NaN                NaN                   NaN
# 4                    NaN                NaN                   NaN
# ...                  ...                ...                   ...
# 38493                NaN                NaN                   NaN
# 38494                NaN                NaN                   NaN
# 38495                NaN                NaN                   NaN
# 38496                NaN                NaN                   NaN
# 38497                NaN                NaN                 93.64
#
# [38498 rows x 10 columns]

# %% [markdown]
# # x_col,y_col

# %%
x_col = list(set([xf]+可控變數+不可控變數)&(set(df_x.columns)))
y_col = list(set([xe,xr])&set(df_y.columns))
print(x_col,y_col)
print(len(x_col),len(y_col))
df = df_x[x_col].join(df_y[y_col])
for i in df.columns:
    df[i] = pd.to_numeric(df[i],errors='coerce')
df
# Out:
# ['ARO2-LIMS-S708@Sulfur', 'ARO2-LIMS-S708@A10+', 'ARO2-DCS-R911_2_HF', 'ARO2-DCS-FI93201', 'ARO2-DCS-R911_2_A_FA', 'ARO2-DCS-FI94701', 'ARO2-DCS-FI914A3', 'ARO2-DCS-R911_2_L3_A', 'ARO2-LIMS-S708@Br.Index', 'ARO2-DCS-FI914A2', 'ARO2-DCS-FI91701', 'ARO2-DCS-FI91601', 'ARO2-DCS-R911_2_L2_A', 'ARO2-LIMS-S708@Water', 'ARO2-DCS-R911_2_XF', 'ARO2-LIMS-S708@A9', 'ARO2-DCS-R911_2_L4_A'] ['ARO2-LIMS-S905@PX', 'ARO2-LIMS-S907@PX']
# 17 2
#        ARO2-LIMS-S708@Sulfur  ARO2-LIMS-S708@A10+  ARO2-DCS-R911_2_HF  \
# 0                        NaN                  NaN          129.987991
# 1                       0.04                  0.0          129.987991
# 2                        NaN                  NaN          129.987991
# 3                        NaN                  NaN          129.987991
# 4                        NaN                  NaN          129.987991
# ...                      ...                  ...                 ...
# 38492                    NaN                  NaN          131.988205
# 38493                    NaN                  NaN          131.988205
# 38494                    NaN                  NaN          131.988205
# 38495                    NaN                  NaN          131.988205
# 38496                    NaN                  NaN          131.988205
#
#        ARO2-DCS-FI93201  ARO2-DCS-R911_2_A_FA  ARO2-DCS-FI94701  \
# 0            902.855225                 0.480        367.023285
# 1            903.495972                 0.480        362.474274
# 2            902.621216                 0.480        371.956207
# 3            905.850281                 0.480        368.045868
# 4            913.898193                 0.480        365.437500
# ...                 ...                   ...               ...
# 38492        905.000000                 0.502        359.561462
# 38493        905.000000                 0.502        358.138519
# 38494        905.000000                 0.502        359.651581
# 38495        905.000000                 0.502        365.950928
# 38496        905.000000                 0.502        363.109314
#
#        ARO2-DCS-FI914A3  ARO2-DCS-R911_2_L3_A  ARO2-LIMS-S708@Br.Index  \
# 0           1784.315796              1.509901                      NaN
# 1           1782.795166              1.509901                    10.08
# 2           1804.128662              1.509901                      NaN
# 3           1769.391846              1.509901                      NaN
# 4           1792.087646              1.509901                      NaN
# ...                 ...                   ...                      ...
# 38492       1503.358398              1.535203                      NaN
# 38493       1512.720093              1.535203                      NaN
# 38494       1518.100586              1.535203                      NaN
# 38495       1559.107544              1.535203                      NaN
# 38496       1558.405762              1.535203                      NaN
#
#        ARO2-DCS-FI914A2  ARO2-DCS-FI91701  ARO2-DCS-FI91601  \
# 0           1494.599609        620.703979        568.646179
# 1           1562.321289        607.068298        559.993713
# 2           2066.136475        613.179688        562.090881
# 3           2054.372314        616.875000        569.152771
# 4           2064.682129        614.364014        564.981323
# ...                 ...               ...               ...
# 38492       1192.466187        629.368591        545.488342
# 38493       1192.965698        576.146851        508.997894
# 38494       1190.868408        636.753174        541.041016
# 38495       1847.302979        638.237244        547.967651
# 38496       1851.685181        634.467468        548.199829
#
#        ARO2-DCS-R911_2_L2_A  ARO2-LIMS-S708@Water  ARO2-DCS-R911_2_XF  \
# 0                  0.315932                   NaN          122.012199
# 1                  0.315643             78.699997          122.012199
# 2                  0.315122                   NaN          122.012199
# 3                  0.314822                   NaN          122.012199
# 4                  0.314041                   NaN          122.012199
# ...                     ...                   ...                 ...
# 38492              0.372907                   NaN          125.987595
# 38493              0.372907                   NaN          125.987595
# 38494              0.372907                   NaN          125.987595
# 38495              0.372907                   NaN          125.987595
# 38496              0.372907                   NaN          125.987595
#
#        ARO2-LIMS-S708@A9  ARO2-DCS-R911_2_L4_A  ARO2-LIMS-S905@PX  \
# 0                    NaN             -0.590059                NaN
# 1                  0.006             -0.590059              0.409
# 2                    NaN             -0.590059                NaN
# 3                    NaN             -0.590059                NaN
# 4                    NaN             -0.590059                NaN
# ...                  ...                   ...                ...
# 38492                NaN             -0.620062                NaN
# 38493                NaN             -0.620062                NaN
# 38494                NaN             -0.620062                NaN
# 38495                NaN             -0.620062                NaN
# 38496                NaN             -0.620062                NaN
#
#        ARO2-LIMS-S907@PX
# 0                    NaN
# 1              34.433998
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 38492                NaN
# 38493                NaN
# 38494                NaN
# 38495                NaN
# 38496                NaN
#
# [38497 rows x 19 columns]

# %% [markdown]
# # miss value

# %%
missing_values_table(df)
# Out:
# Your selected dataframe has 19 columns.
# There are 19 columns that have missing values.
#                          Missing Values  % of Total Values
# ARO2-LIMS-S708@Sulfur             37164               96.5
# ARO2-LIMS-S905@PX                 37164               96.5
# ARO2-LIMS-S907@PX                 37162               96.5
# ARO2-LIMS-S708@Br.Index           37137               96.5
# ARO2-LIMS-S708@Water              34654               90.0
# ARO2-LIMS-S708@A10+               34632               90.0
# ARO2-LIMS-S708@A9                 34617               89.9
# ARO2-DCS-FI93201                      1                0.0
# ARO2-DCS-R911_2_A_FA                  1                0.0
# ARO2-DCS-FI94701                      1                0.0
# ARO2-DCS-FI914A3                      1                0.0
# ARO2-DCS-R911_2_L3_A                  1                0.0
# ARO2-DCS-FI91701                      1                0.0
# ARO2-DCS-FI91601                      1                0.0
# ARO2-DCS-R911_2_L2_A                  1                0.0
# ARO2-DCS-R911_2_XF                    1                0.0
# ARO2-DCS-R911_2_L4_A                  1                0.0
# ARO2-DCS-R911_2_HF                    1                0.0
# ARO2-DCS-FI914A2                      1                0.0

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
mmx = MinMaxScaler()
df[:] = mmx.fit_transform(df[:])
new_x_col = []
for i in x_col:
    n =  get_interval(df,i)
    if n == 1:
        new_x_col.append(i)
new_y_col = []
for i in y_col:
    n = get_interval(df,i)
    if n == 24:
        new_y_col.append(i)
x_col = new_x_col
y_col = new_y_col
df.head()
# Out:
#    ARO2-LIMS-S708@Sulfur  ARO2-LIMS-S708@A10+  ARO2-DCS-R911_2_HF  \
# 0                    NaN                  NaN            0.984846
# 1               0.034843                  0.0            0.984846
# 2                    NaN                  NaN            0.984846
# 3                    NaN                  NaN            0.984846
# 4                    NaN                  NaN            0.984846
#
#    ARO2-DCS-FI93201  ARO2-DCS-R911_2_A_FA  ARO2-DCS-FI94701  ARO2-DCS-FI914A3  \
# 0          0.931893              0.076858          0.845057          0.832968
# 1          0.932554              0.076858          0.834584          0.832258
# 2          0.931651              0.076858          0.856415          0.842217
# 3          0.934984              0.076858          0.847412          0.826001
# 4          0.943291              0.076858          0.841406          0.836596
#
#    ARO2-DCS-R911_2_L3_A  ARO2-LIMS-S708@Br.Index  ARO2-DCS-FI914A2  \
# 0              0.889945                      NaN          0.708810
# 1              0.889945                 0.203556          0.740927
# 2              0.889945                      NaN          0.979860
# 3              0.889945                      NaN          0.974281
# 4              0.889945                      NaN          0.979171
#
#    ARO2-DCS-FI91701  ARO2-DCS-FI91601  ARO2-DCS-R911_2_L2_A  \
# 0          0.948052          0.966329              0.063262
# 1          0.927225          0.951625              0.062558
# 2          0.936559          0.955189              0.061286
# 3          0.942203          0.967189              0.060556
# 4          0.938368          0.960101              0.058650
#
#    ARO2-LIMS-S708@Water  ARO2-DCS-R911_2_XF  ARO2-LIMS-S708@A9  \
# 0                   NaN            0.938642                NaN
# 1              0.000936            0.938642           0.085714
# 2                   NaN            0.938642                NaN
# 3                   NaN            0.938642                NaN
# 4                   NaN            0.938642                NaN
#
#    ARO2-DCS-R911_2_L4_A  ARO2-LIMS-S905@PX  ARO2-LIMS-S907@PX
# 0               0.95784                NaN                NaN
# 1               0.95784           0.009175           0.745036
# 2               0.95784                NaN                NaN
# 3               0.95784                NaN                NaN
# 4               0.95784                NaN                NaN

# %% [markdown]
# # build_time_series_dataset

# %%
data = build_time_series_dataset(df.dropna(),x_col,y_col,n=24)
def flatten_dataset(data):
    b = data['X'].shape[0]
    t = data['X'].shape[1]
    f = data['X'].shape[2]
    X = data['X'].reshape(b,t*f)
    Y = data['Y']
    X = pd.DataFrame(X,columns=['x'+str(i) for i in range(t*f)])#.join(pd.DataFrame(data['Y']))
    Y = pd.DataFrame(Y,columns=['y'+str(i) for i in range(data['Y'].shape[1])])
    df = X.join(Y)
    x_col = X.columns
    y_col = Y.columns
    return df,x_col,y_col
df,x_col,y_col = flatten_dataset(data)
display(df.head())
print(x_col,y_col)
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 604.37it/s]
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  0.984846  0.932554  0.076858  0.834584  0.832258  0.889945  0.740927
# 1  0.984846  0.950879  0.076858  0.841969  0.720565  0.876377  0.868807
# 2  0.984846  0.946302  0.076858  0.839465  0.720119  0.876377  0.845526
# 3  0.984846  0.951232  0.069172  0.837953  0.841021  0.876377  0.981314
# 4  0.984846  0.898209  0.084544  0.836100  0.958758  0.876377  0.670908
#
#          x7        x8        x9  ...      x280      x281      x282      x283  \
# 0  0.927225  0.951625  0.062558  ...  0.954837  0.876377  0.683867  0.949181
# 1  0.962679  0.973522  0.070508  ...  0.973869  0.876377  0.681876  0.954316
# 2  0.952085  0.960084  0.073143  ...  0.693029  0.876377  0.986472  0.956321
# 3  0.949109  0.965997  0.070508  ...  0.689981  0.876377  0.555564  0.930215
# 4  0.933884  0.945404  0.065897  ...  0.718480  0.876377  0.839380  0.944462
#
#        x284      x285      x286      x287        y0        y1
# 0  0.967562  0.065897  0.961723  0.926221  0.006542  0.799207
# 1  0.971851  0.070508  0.969225  0.926221  0.014618  0.799575
# 2  0.970512  0.068532  0.969225  0.926221  0.018145  0.798491
# 3  0.949771  0.058650  0.969225  0.936761  0.017890  0.785052
# 4  0.958721  0.075778  0.969225  0.915681  0.003271  0.798773
#
# [5 rows x 290 columns]
# Index(['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9',
#        ...
#        'x278', 'x279', 'x280', 'x281', 'x282', 'x283', 'x284', 'x285', 'x286',
#        'x287'],
#       dtype='object', length=288) Index(['y0', 'y1'], dtype='object')

# %% [markdown]
# # pd.to_numeric

# %%
for i in df.columns:
    df[i] = pd.to_numeric(df[i],errors='coerce')
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # build_mlp

# %%
model = build_mlp(
    layers=[len(x_col),256,128,64,len(y_col)],
    activation_function=nn.ReLU(),
    output_activation_function=nn.Sigmoid())
model
# Out:
# Sequential(
#   (0): Linear(in_features=288, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=64, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=64, out_features=2, bias=True)
#   (7): Sigmoid()
# )

# %% [markdown]
# # train_loop

# %%
import torch
from tqdm import tqdm
from copy import deepcopy
import matplotlib.pyplot as plt
train_loader,val_loader = df_2_torch_data_iter(df,x_col,y_col,batch_size=8)
optimizer = torch.optim.Adam(model.parameters())
device = 'cpu'
loss_fn = nn.SmoothL1Loss()
best_model,history = train_loop(model,train_loader,val_loader,optimizer,device,loss_fn,max_epochs=40)
plt.plot(history['train_loss'])
plt.plot(history['val_loss'])
plt.show()
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 294.88it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1002.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 417.82it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.86it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 345.12it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 278.51it/s]
# 100%|██████████| 2/2 [00:00<00:00, 999.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.34it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.31it/s]
# epoch:0 train_loss:0.07401381433010101 val_loss:0.06527342274785042
# save best_model now_val_best_loss is:0.06527342274785042
# epoch:1 train_loss:0.019903257372789085 val_loss:0.009935201611369848
# save best_model now_val_best_loss is:0.009935201611369848
# epoch:2 train_loss:0.008100269245915115 val_loss:0.013150084298104048
# epoch:3 train_loss:0.008081509789917618 val_loss:0.0059050400741398335
# save best_model now_val_best_loss is:0.0059050400741398335
# epoch:4 train_loss:0.0030606013315264136 val_loss:0.0034165107645094395
# save best_model now_val_best_loss is:0.0034165107645094395
# epoch:5 train_loss:0.0031339517736341804 val_loss:0.00174456431705039
# save best_model now_val_best_loss is:0.00174456431705039
# epoch:6 train_loss:0.0019034033612115309 val_loss:0.0025821896851994097
# epoch:7 train_loss:0.0023978408135008067 val_loss:0.0015907658089417964
# save best_model now_val_best_loss is:0.0015907658089417964
# 100%|██████████| 5/5 [00:00<00:00, 294.91it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 263.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 334.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.91it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 278.42it/s]]
# 100%|██████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 385.62it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.57it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# epoch:8 train_loss:0.0019921301282010972 val_loss:0.0019460301264189184
# epoch:9 train_loss:0.0019128233907395042 val_loss:0.0014814904900504189
# save best_model now_val_best_loss is:0.0014814904900504189
# epoch:10 train_loss:0.0018027491678367369 val_loss:0.0016205225110752508
# epoch:11 train_loss:0.001877069313195534 val_loss:0.0014800844187448092
# save best_model now_val_best_loss is:0.0014800844187448092
# epoch:12 train_loss:0.0018367345983278938 val_loss:0.0015370247638202272
# epoch:13 train_loss:0.0017722782940836623 val_loss:0.001476776893468923
# save best_model now_val_best_loss is:0.001476776893468923
# epoch:14 train_loss:0.0017901782994158566 val_loss:0.0014795447041251464
# epoch:15 train_loss:0.0018017638576566242 val_loss:0.0014796919876971515
# 100%|██████████| 5/5 [00:00<00:00, 263.87it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.30it/s]]
# 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 278.53it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 278.51it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 263.86it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 278.52it/s]]
# 100%|██████████| 2/2 [00:00<00:00, 1002.46it/s]
# 100%|██████████| 5/5 [00:00<00:00, 296.40it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.15it/s]
# epoch:16 train_loss:0.0017822469817474484 val_loss:0.0014723300337209366
# save best_model now_val_best_loss is:0.0014723300337209366
# epoch:17 train_loss:0.0017656490308581851 val_loss:0.001467849665459653
# save best_model now_val_best_loss is:0.001467849665459653
# epoch:18 train_loss:0.0017771318016457371 val_loss:0.0014652405211563746
# save best_model now_val_best_loss is:0.0014652405211563746
# epoch:19 train_loss:0.0017739512986736372 val_loss:0.0014676415239591734
# epoch:20 train_loss:0.0017615995238884352 val_loss:0.0014632499651270336
# save best_model now_val_best_loss is:0.0014632499651270336
# epoch:21 train_loss:0.0017600750215933658 val_loss:0.0014624483228544705
# save best_model now_val_best_loss is:0.0014624483228544705
# epoch:22 train_loss:0.0017610847935429774 val_loss:0.0014633922455686843
# 100%|██████████| 5/5 [00:00<00:00, 286.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.34it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 334.21it/s]]
# 100%|██████████| 2/2 [00:00<00:00, 667.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 334.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1002.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.91it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 286.35it/s]]
# 100%|██████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 323.19it/s]
# epoch:23 train_loss:0.0017549374533700757 val_loss:0.0014632423590228427
# epoch:24 train_loss:0.0017498867164249532 val_loss:0.0014629559173044981
# epoch:25 train_loss:0.0017491984253865667 val_loss:0.0014643030317529337
# epoch:26 train_loss:0.0017467120123910718 val_loss:0.0014661632994830143
# epoch:27 train_loss:0.0017429356448701583 val_loss:0.0014676359242002945
# epoch:28 train_loss:0.0017412401211913675 val_loss:0.0014697290935146157
# epoch:29 train_loss:0.0017401811855961569 val_loss:0.0014723353779118042
# epoch:30 train_loss:0.0017382507721777074 val_loss:0.00147472904791357
# 100%|██████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 286.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 279.43it/s]
# 100%|██████████| 2/2 [00:00<00:00, 666.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 313.34it/s]]
# 100%|██████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 334.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1002.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 358.06it/s]
# 100%|██████████| 2/2 [00:00<00:00, 501.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 668.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 294.91it/s]]
# epoch:31 train_loss:0.001736821337544825 val_loss:0.001476962508604629
# epoch:32 train_loss:0.001736167490889784 val_loss:0.001479121667216532
# epoch:33 train_loss:0.001735358360747341 val_loss:0.001481152641645167
# epoch:34 train_loss:0.0017343628569506109 val_loss:0.0014827217746642418
# epoch:35 train_loss:0.0017338631732854992 val_loss:0.001484043361415388
# epoch:36 train_loss:0.0017334019285044633 val_loss:0.0014850957013550214
# epoch:37 train_loss:0.0017327187597402371 val_loss:0.0014857966380077414
# epoch:38 train_loss:0.0017321393461315893 val_loss:0.0014862590142001864
# 100%|██████████| 2/2 [00:00<00:00, 501.20it/s]
# 100%|██████████| 40/40 [00:01<00:00, 39.77it/s]
# epoch:39 train_loss:0.0017316525045316666 val_loss:0.0014865655939502176

# %% [markdown]
# # mape

# %%
def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape
y_pred = model(torch.FloatTensor(df[x_col].values)).detach().numpy()
y_real = df[y_col].values
MAPE(y_pred,y_real)
# Out:
# 35.7440259646079
